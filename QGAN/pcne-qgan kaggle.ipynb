# %% [markdown]
# # Position-Conditioned Noise Encoder based Quantum GAN

# %%
# !pip install jax jaxlib

# %%
# !pip install -U "jax[cuda13]"

# %%
# !pip install pennylane tensorcircuit-ng

# %%
# # 1. Nuclear option: remove all potential JAX conflicts
# !pip uninstall -y jax jaxlib jax-cuda12-plugin jax-cuda13-plugin jax-cuda12-pjrt jax-cuda13-pjrt

# # 2. Reinstall ONLY the one that matches your drivers (usually cuda12 is safest)
# !pip install -U "jax[cuda13]"

# %%
# !pip install pennylane-lightning-gpu

# %%
# !pip install gast

# %%
import os
import random

import jax
import jax.numpy as jnp

os.environ['TORCH_USE_CUDA_DSA'] = "1"
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"
os.environ["XLA_FLAGS"] = "--xla_gpu_force_compilation_parallelism=1"

# Verify with the new 2026 JAX backend check
import jax
from jax.extend import backend
try:
    print(f"Active Backend: {backend.get_backend().platform}")
    print(f"Devices: {jax.devices()}")
except Exception as e:
    print(f"Error: {e}")

import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data

import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
from torchvision import datasets, transforms
import torchvision.transforms as transforms

from torch.utils.dlpack import from_dlpack as f2d, to_dlpack as t2d
# from jax.dlpack import from_dlpack as d2j, to_dlpack as j2d
from jax.dlpack import from_dlpack as d2j
# from jax.numpy import from_dlpack as d2j, to_dlpack as j2d
# from jax.numpy import from_dlpack as d2j

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import pennylane as qml

from tqdm import tqdm
from matplotlib import cm
from scipy.linalg import sqrtm
from sklearn.decomposition import PCA

import tensorcircuit as tc

K = tc.set_backend("jax")
print("K:", K)

import time
# Out:
# Active Backend: gpu
# Devices: [CudaDevice(id=0)]
# K: jax_backend

# %%
def j2d(x, stream=None):
    return x.__dlpack__(stream=stream)

# %%
cudnn.benchmark = True

if torch.accelerator.is_available():
    device = torch.accelerator.current_accelerator()
else:
    device = torch.device("cpu")

print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
def get_train_data(dataset='MNIST', ds_class=5):
    if dataset == 'MNIST':
        train_loader = torch.utils.data.DataLoader(datasets.MNIST('../mnist', 
                                                                download=True, 
                                                                train=True,
                                                                
                                                                transform=transforms.Compose([
                                                                    torchvision.transforms.ToTensor(),
                                                                    transforms.Lambda(torch.flatten),
                                                                ])), 
                                                batch_size=10000, 
                                                shuffle=True)
    elif dataset == 'Fashion':
        train_loader = torch.utils.data.DataLoader(datasets.FashionMNIST('../fashion', 
                                                                download=True, 
                                                                train=True,
                                                                
                                                                transform=transforms.Compose([
                                                                    torchvision.transforms.ToTensor(),
                                                                    transforms.Lambda(torch.flatten),
                                                                ])), 
                                                batch_size=10000, 
                                                shuffle=True)
    elif dataset == 'KMNIST':
        train_loader = torch.utils.data.DataLoader(datasets.FashionMNIST('../kmnist', 
                                                                download=True, 
                                                                train=True,
                                                                
                                                                transform=transforms.Compose([
                                                                    torchvision.transforms.ToTensor(),
                                                                    transforms.Lambda(torch.flatten),
                                                                ])), 
                                                batch_size=10000, 
                                                shuffle=True)
    elif dataset == 'QMNIST':
        train_loader = torch.utils.data.DataLoader(datasets.FashionMNIST('../qmnist', 
                                                                download=True, 
                                                                train=True,
                                                                
                                                                transform=transforms.Compose([
                                                                    torchvision.transforms.ToTensor(),
                                                                    transforms.Lambda(torch.flatten),
                                                                ])), 
                                                batch_size=10000, 
                                                shuffle=True)
    elif dataset == 'EMNIST':
        train_loader = torch.utils.data.DataLoader(datasets.FashionMNIST('../emnist', 
                                                                download=True, 
                                                                train=True,
                                                                
                                                                transform=transforms.Compose([
                                                                    torchvision.transforms.ToTensor(),
                                                                    transforms.Lambda(torch.flatten),
                                                                ])), 
                                                batch_size=10000, 
                                                shuffle=True)
    train_data = []
    label_to_keep = ds_class
    label_to_keep_name = str(label_to_keep)
    for (data, labels) in train_loader:
        for x, y in zip(data, labels):
            if y == label_to_keep:
                train_data.append(x.numpy())

    return label_to_keep_name, train_data

# %%
def scale_data(data, scale=None, dtype=np.float32):
    if scale is None:
        scale = [-1, 1]
    min_data, max_data = [float(np.min(data)), float(np.max(data))]
    min_scale, max_scale = [float(scale[0]), float(scale[1])]
    data = ((max_scale - min_scale) * (data - min_data) / (max_data - min_data)) + min_scale
    return data.astype(dtype)

# %%
# Function from https://machinelearningmastery.com/how-to-implement-the-frechet-inception-distance-fid-from-scratch/
def calculate_fid(act1, act2):
    mu1, sigma1 = act1.mean(axis=0), np.cov(act1, rowvar=False)
    mu2, sigma2 = act2.mean(axis=0), np.cov(act2, rowvar=False)
    ssdiff = np.sum((mu1 - mu2)**2.0)
    covmean = sqrtm(sigma1.dot(sigma2))
    if np.iscomplexobj(covmean):
        covmean = covmean.real
    fid = ssdiff + np.trace(sigma1 + sigma2 - 2.0 * covmean)
    return fid

def calculate_fid(act1, act2, eps=1e-6):
    mu1, sigma1 = act1.mean(axis=0), np.cov(act1, rowvar=False)
    mu2, sigma2 = act2.mean(axis=0), np.cov(act2, rowvar=False)
    offset = np.eye(sigma1.shape[0]) * eps
    sigma1_stable = sigma1 + offset
    sigma2_stable = sigma2 + offset

    sigma1, sigma2 = sigma1_stable, sigma2_stable
    
    ssdiff = np.sum((mu1 - mu2)**2.0)
    covmean = sqrtm(sigma1.dot(sigma2))
    if np.iscomplexobj(covmean):
        covmean = covmean.real
    fid = ssdiff + np.trace(sigma1 + sigma2 - 2.0 * covmean)
    return fid

# %%
label_to_keep_name, train_data = get_train_data(dataset='MNIST')

# %%
train_data = scale_data(np.array(train_data), [0,1])

# %%
pca_dims=40

# %%
pca = PCA(n_components=pca_dims)
pca_data_full = pca.fit_transform(train_data)

# %%
label_to_keep_name
# Out:
# '5'

# %%
pca_data_full.shape, train_data.shape
# Out:
# ((5421, 40), (5421, 784))

# %%
image_size = 8
position_encoding = 0
batch_size = 32
n_qubits = image_size + (position_encoding)
q_depth = 6 
n_generators = 5

# %%
ordering = []

# %%
# for i in range(8):
for i in range(n_generators):
    k = (image_size-1)*i
    l = [n_generators*image_size - i - k for i in range(1, image_size)]
    ordering.append([i] + (l[::-1] if i%2==1 else l))
pca_min, pca_max = np.min(pca_data_full), np.max(pca_data_full)

# %%
full_train_data = [(i,j) for i,j in zip(scale_data(pca_data_full), train_data)]

transform = transforms.Compose([transforms.ToTensor()])
dataloader = torch.utils.data.DataLoader(
    scale_data(pca_data_full), batch_size=batch_size, shuffle=True, drop_last=True
)

# %%
class D_PCNE_QGAN(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(pca_dims, 64),
            nn.ReLU(),
            nn.Linear(64, 16),
            nn.ReLU(),
            nn.Linear(16, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.model(x)

# %%
# dev = qml.device("lightning.qubit", wires=n_qubits)
# dev = qml.device("lightning.gpu", wires=n_qubits)
dev = qml.device("default.qubit", wires=n_qubits)

# @qml.qnode(dev, interface="torch", diff_method="parameter-shift")
# @qml.qnode(dev, interface="jax", diff_method="parameter-shift")

# @qml.qnode(dev, interface="jax", diff_method="parameter-shift")
# @qml.qnode(dev, interface="torch", diff_method="parameter-shift")
# @jax.jit
# @qml.qnode(dev, interface="jax")
# def quantum_circuit_PCNE_QGAN(inputs, weights, weights_ne):  # input: (32, 8, 5) -> (32, 8, 5+1)
#     # # weights = weights.reshape(q_depth, n_qubits)
#     # for i in range(n_qubits):
#     #     qml.RY(inputs[i], wires=i)
#     #     qml.RX(inputs[i], wires=i)
#     qml.AngleEmbedding(features=inputs, wires=range(n_qubits), rotation='Y')
#     qml.AngleEmbedding(features=inputs, wires=range(n_qubits), rotation='X')

#     q_depth_ne, n_qubits_full = weights_ne.shape
#     q_depth_vqc, n_qubits_vqc = weights.shape

#     assert n_qubits_full == n_qubits_vqc + position_encoding
#     assert n_qubits_full == n_qubits
    
#     for i in range(q_depth_ne):
#         for y in range(n_qubits):
#             qml.RY(weights_ne[i][y], wires=y)
#         for y in range(n_qubits):
#             qml.CZ(wires=[y, (y + 1)%n_qubits])

#     for i in range(q_depth_vqc):
#         for y in range(n_qubits_vqc):
#             qml.RY(weights[i][y], wires=y)
#         for y in range(n_qubits_vqc):
#             qml.CZ(wires=[y, (y + 1)%n_qubits_vqc])
    
#     return [qml.expval(qml.PauliX(i)) for i in range(n_qubits_vqc)]

@jax.jit
@qml.qnode(dev, interface="jax")
def quantum_circuit_PCNE_QGAN(inputs, weights):  # input: (32, 8, 5) -> (32, 8, 5+1)
    # # weights = weights.reshape(q_depth, n_qubits)
    # for i in range(n_qubits):
    #     qml.RY(inputs[i], wires=i)
    #     qml.RX(inputs[i], wires=i)
    qml.AngleEmbedding(features=inputs, wires=range(n_qubits), rotation='Y')
    qml.AngleEmbedding(features=inputs, wires=range(n_qubits), rotation='X')
    
    q_depth_vqc, n_qubits_vqc = weights.shape
    
    assert n_qubits_full == n_qubits

    for i in range(q_depth_vqc):
        for y in range(n_qubits_vqc):
            qml.RY(weights[i][y], wires=y)
        for y in range(n_qubits_vqc):
            qml.CZ(wires=[y, (y + 1)%n_qubits_vqc])
    
    return [qml.expval(qml.PauliX(i)) for i in range(n_qubits_vqc)]

@jax.jit
@qml.qnode(dev, interface="jax")
def quantum_circuit_MOSAIQ(inputs, weights):  # input: (32, 8, 5) -> (32, 8, 5+1)
    # # weights = weights.reshape(q_depth, n_qubits)
    # for i in range(n_qubits):
    #     qml.RY(inputs[i], wires=i)
    #     qml.RX(inputs[i], wires=i)
    qml.AngleEmbedding(features=inputs, wires=range(n_qubits), rotation='Y')
    qml.AngleEmbedding(features=inputs, wires=range(n_qubits), rotation='X')
    
    q_depth_vqc, n_qubits_vqc = weights.shape
    
    # assert n_qubits_full == n_qubits

    for i in range(q_depth_vqc):
        for y in range(n_qubits_vqc):
            qml.RY(weights[i][y], wires=y)
        for y in range(n_qubits_vqc):
            qml.CZ(wires=[y, (y + 1)%n_qubits_vqc])
    
    return [qml.expval(qml.PauliX(i)) for i in range(n_qubits_vqc)]

# %%
ordering
# Out:
# [[0, 39, 38, 37, 36, 35, 34, 33],
#  [1, 26, 27, 28, 29, 30, 31, 32],
#  [2, 25, 24, 23, 22, 21, 20, 19],
#  [3, 12, 13, 14, 15, 16, 17, 18],
#  [4, 11, 10, 9, 8, 7, 6, 5]]

# %%
jax_circuit__1 = jax.jit(quantum_circuit_PCNE_QGAN)
vmap_circuit = jax.vmap(jax_circuit__1, in_axes=(0, None, None))

jax_circuit__2 = jax.jit(quantum_circuit_MOSAIQ)
vmap_circuit = jax.vmap(jax_circuit__2, in_axes=(0, None))

# %%
class JAXQuantumFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, inputs, weights, weights_ne):
        jax_gpu = jax.devices("gpu")[0]
        # jax_in = jax.device_put(d2j(t2d(inputs.detach())), jax_gpu)
        # jax_w = jax.device_put(d2j(t2d(weights.detach())), jax_gpu)
        # jax_w_ne = jax.device_put(d2j(t2d(weights_ne.detach())), jax_gpu)

        jax_in = jax.device_put(d2j(inputs.detach()).reshape(-1, n_qubits), jax_gpu)
        jax_w = jax.device_put(d2j(weights.detach()), jax_gpu)
        jax_w_ne = jax.device_put(d2j(weights_ne.detach()), jax_gpu)
        
        # jax_mixing_weights = jax.device_put(d2j(t2d(mixing_weights.detach())), jax_gpu)
        
        # 1. Define a wrapper that ensures the output is ALWAYS a JAX array
        # This allows JAX to 'trace' the stacking logic
        def consolidated_model(i, w, w_ne):
            # print("shape of i, w, w_ne in JAXQuantumFunction:", i.shape, w.shape, w_ne.shape)
            out = vmap_circuit(i, w, w_ne)
            # print("shape of out in JAXQuantumFunction:", out.shape)
            if isinstance(out, (list, tuple)):
                return jnp.stack(out, axis=-1)
            return out

        # 2. Compute VJP on the consolidated model
        val, jax_vjp_fn = jax.vjp(consolidated_model, jax_in, jax_w, jax_w_ne)
        
        ctx.jax_vjp_fn = jax_vjp_fn
        # Return to Torch
        return f2d(j2d(val))

    @staticmethod
    def backward(ctx, grad_output):
        # 1. Detect device from the incoming gradient
        current_device = grad_output.device
        jax_gpu = jax.devices("gpu")[0]
        
        # 2. Convert to JAX for calculation
        # jax_grad_out = jax.device_put(d2j(t2d(grad_output.detach())), jax_gpu)
        jax_grad_out = jax.device_put(d2j(grad_output.detach().contiguous()), jax_gpu)
        
        # 3. JAX backward pass
        # grad_inputs, grad_weights, grad_mixing = ctx.jax_vjp_fn(jax_grad_out)
        grad_inputs, grad_weights, grad_weights_ne = ctx.jax_vjp_fn(jax_grad_out)
        
        # 4. Convert back to Torch and FORCE the device metadata
        # We use .to(current_device) to ensure it matches exactly
        # return (
        #     f2d(j2d(grad_inputs)).to(current_device), 
        #     f2d(j2d(grad_weights)).to(current_device),
        #     f2d(j2d(grad_weights_ne)).to(current_device)
        #     # f2d(j2d(grad_mixing)).to(current_device)
        # )

        return (
            f2d(grad_inputs).to(current_device), 
            f2d(grad_weights).to(current_device),
            f2d(grad_weights_ne).to(current_device)
            # f2d(j2d(grad_mixing)).to(current_device)
        )

# %%
class JAXQuantumFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, inputs, weights):
        jax_gpu = jax.devices("gpu")[0]
        # jax_in = jax.device_put(d2j(t2d(inputs.detach())), jax_gpu)
        # jax_w = jax.device_put(d2j(t2d(weights.detach())), jax_gpu)
        # jax_w_ne = jax.device_put(d2j(t2d(weights_ne.detach())), jax_gpu)

        jax_in = jax.device_put(d2j(inputs.detach()).reshape(-1, n_qubits), jax_gpu)
        jax_w = jax.device_put(d2j(weights.detach()), jax_gpu)
        
        # jax_mixing_weights = jax.device_put(d2j(t2d(mixing_weights.detach())), jax_gpu)
        
        # 1. Define a wrapper that ensures the output is ALWAYS a JAX array
        # This allows JAX to 'trace' the stacking logic
        def consolidated_model(i, w):
            # print("shape of i, w, w_ne in JAXQuantumFunction:", i.shape, w.shape, w_ne.shape)
            out = vmap_circuit(i, w)
            # print("shape of out in JAXQuantumFunction:", out.shape)
            if isinstance(out, (list, tuple)):
                return jnp.stack(out, axis=-1)
            return out

        # 2. Compute VJP on the consolidated model
        val, jax_vjp_fn = jax.vjp(consolidated_model, jax_in, jax_w)
        
        ctx.jax_vjp_fn = jax_vjp_fn
        # Return to Torch
        return f2d(j2d(val))

    @staticmethod
    def backward(ctx, grad_output):
        # 1. Detect device from the incoming gradient
        current_device = grad_output.device
        jax_gpu = jax.devices("gpu")[0]
        
        # 2. Convert to JAX for calculation
        # jax_grad_out = jax.device_put(d2j(t2d(grad_output.detach())), jax_gpu)
        jax_grad_out = jax.device_put(d2j(grad_output.detach().contiguous()), jax_gpu)
        
        # 3. JAX backward pass
        # grad_inputs, grad_weights, grad_mixing = ctx.jax_vjp_fn(jax_grad_out)
        grad_inputs, grad_weights = ctx.jax_vjp_fn(jax_grad_out)

        return (
            f2d(grad_inputs).to(current_device), 
            f2d(grad_weights).to(current_device)
        )

# %%
n_generators
# Out:
# 5

# %%
class QuantumMLP(nn.Module):
    def __init__(self, q_delta, q_depth, q_depth_ne, n_qubits, position_encoding, name='QuantumMLP'):
        super().__init__()
        self.name = name
        # Define weights as PyTorch parameters so Adam can optimize them
        # self.vqc_weights = nn.Parameter(torch.randn(weights_shape).to(torch.device('cuda')))
        # self.vqc_weights = nn.Parameter(torch.zeros(weights_shape).to(torch.device('cuda')))
        
        # self.q_params = nn.ParameterList(
        #     [nn.Parameter(q_delta * torch.rand(q_depth, n_qubits-position_encoding), requires_grad=True),
        #      nn.Parameter(q_delta * torch.rand(q_depth_ne, n_qubits), requires_grad=True)]
        # )

        self.q_params = nn.ParameterList(
            [nn.Parameter(q_delta * torch.rand(q_depth, n_qubits-position_encoding), requires_grad=True)]
        )
        
        # self.mixing_weights = nn.Parameter(torch.randn(mixing_weights).to(torch.device('cuda')))

    def forward(self, x):
        # out = JAXQuantumFunction.apply(x, self.q_params[0], self.q_params[1])
        print("shape of x:", x.shape)
        out = JAXQuantumFunction.apply(x, self.q_params[0])
        
        return out

# %%
class QuantumMLP_MOSAIQ(nn.Module):
    def __init__(self, name='QuantumMLP_MOSAIQ'):
        super().__init__()
        self.name = name

    def forward(self, x, weight):
        # out = JAXQuantumFunction.apply(x, self.q_params[0], self.q_params[1])
        # print("shape of x:", x.shape)
        out = JAXQuantumFunction.apply(x, weight)
        
        return out

# %%
class QuantumGenerator_PCNE_QGAN(nn.Module):
    def __init__(self, n_generators, position_encoding, q_depth_ne, q_depth, q_delta=1, env='simulation'):
        super().__init__()

        # self.q_params = nn.ParameterList(
        #     [
        #         nn.Parameter(q_delta * torch.rand(q_depth, n_qubits), requires_grad=True)
        #         for _ in range(n_generators)
        #     ]
        # )
        # self.q_params = [nn.Parameter(q_delta * torch.rand(q_depth, n_qubits-position_encoding), requires_grad=True),
        #                  nn.Parameter(q_delta * torch.rand(q_depth_ne, n_qubits), requires_grad=True)]

        self.n_generators = n_generators
        self.env = env

        # weight_shapes = {"weights": (q_depth, n_qubits)}
        # if env == "real":
        #     self.qcircuit = qml.qnn.TorchLayer(quantum_cirtui_real_machine, weight_shapes).to(device)
        # else:
        #     self.qcircuit = qml.qnn.TorchLayer(quantum_circuit_MosaiQ, weight_shapes).to(device)

        # weight_shapes = {
        #     "weights": (q_depth, n_qubits-position_encoding),
        #     "weights_ne": (q_depth_ne, n_qubits),
        # }
        
        # init_method = {
        #     "weights": nn.Parameter(q_delta * torch.rand(q_depth, n_qubits-position_encoding), requires_grad=True),
        #     "weights_ne":  nn.Parameter(q_delta * torch.rand(q_depth_ne, n_qubits), requires_grad=True),
        # }
        # self.generator_torch_layer = qml.qnn.TorchLayer(quantum_circuit_PCNE_QGAN, weight_shapes=weight_shapes, init_method=init_method).to(device)
        
        self.generator_torch_layer = QuantumMLP(q_delta, q_depth, q_depth_ne, n_qubits, position_encoding).to(device)
        # self.generator_torch_layer = QuantumMLP_MOSAIQ().to(device)

    def forward(self, x):
        # print("x shape:", x.shape)  # (batch_size, length of noise)
        images = []
        patch_size = image_size
        images = torch.Tensor(x.size(0), 0).to(device)
        batch_size, len_data = x.shape

        x = x.unsqueeze(1)  # (32, 1, 5)
        x = x.expand(-1, n_generators, -1)  # (32, 8, 5)
        # print("x:", x)
        pos_values = torch.linspace(np.pi/4, 2*np.pi, steps=n_generators).to(device)
        pos_values = pos_values.view(1, n_generators, 1)
        pos_values = pos_values.expand(batch_size, -1, -1)  # (32, 8, 5)
        pos_values = pos_values.view(batch_size, n_generators, 1)
        x = torch.cat((x, pos_values), dim=2)
        # print("x:", x)
        # print("x shape:", x.shape)

        output = self.generator_torch_layer(x)
        # output = JAXQuantumFunction.apply(x, self.q_params[0], self.q_params[1])
        # print("output shape:", output.shape)

        output = output.view(batch_size, n_generators, -1)
        output = output.view(batch_size, -1)
        flattened_order = [j for sub in ordering for j in sub]
        # print("output shape:", output.shape)
        output = output[:, flattened_order]
        # print("output shape:", output.shape)
        # output = output.reshape(batch_size, patch_size)
        # print("patches shape:", output.shape)
        
        return output

# %%
class QuantumGenerator_MOSAIQ(nn.Module):
    def __init__(self, n_generators, position_encoding, q_depth_ne, q_depth, q_delta=1, env='simulation'):
        super().__init__()

        self.q_params = nn.ParameterList(
            [
                nn.Parameter(q_delta * torch.rand(q_depth, n_qubits), requires_grad=True)
                for _ in range(n_generators)
            ]
        ).to(device)
        # self.q_params = [nn.Parameter(q_delta * torch.rand(q_depth, n_qubits-position_encoding), requires_grad=True),
        #                  nn.Parameter(q_delta * torch.rand(q_depth_ne, n_qubits), requires_grad=True)]

        self.n_generators = n_generators
        self.env = env

        # weight_shapes = {"weights": (q_depth, n_qubits)}
        # if env == "real":
        #     self.qcircuit = qml.qnn.TorchLayer(quantum_cirtui_real_machine, weight_shapes).to(device)
        # else:
        #     self.qcircuit = qml.qnn.TorchLayer(quantum_circuit_MosaiQ, weight_shapes).to(device)

        # weight_shapes = {
        #     "weights": (q_depth, n_qubits-position_encoding),
        #     "weights_ne": (q_depth_ne, n_qubits),
        # }
        
        # init_method = {
        #     "weights": nn.Parameter(q_delta * torch.rand(q_depth, n_qubits-position_encoding), requires_grad=True),
        #     "weights_ne":  nn.Parameter(q_delta * torch.rand(q_depth_ne, n_qubits), requires_grad=True),
        # }
        # self.generator_torch_layer = qml.qnn.TorchLayer(quantum_circuit_PCNE_QGAN, weight_shapes=weight_shapes, init_method=init_method).to(device)
        
        # self.generator_torch_layer = QuantumMLP(q_delta, q_depth, q_depth_ne, n_qubits, position_encoding).to(device)
        self.generator_torch_layer = QuantumMLP_MOSAIQ().to(device)

    def forward(self, x):
        # print("x shape:", x.shape)  # (batch_size, length of noise)
        images = []
        patch_size = image_size
        images = torch.Tensor(x.size(0), 0).to(device)
        batch_size, len_data = x.shape

        # x = x.unsqueeze(1)  # (32, 1, 5)
        # x = x.expand(-1, n_generators, -1)  # (32, 8, 5)
        # # print("x:", x)
        # pos_values = torch.linspace(np.pi/4, 2*np.pi, steps=n_generators).to(device)
        # pos_values = pos_values.view(1, n_generators, 1)
        # pos_values = pos_values.expand(batch_size, -1, -1)  # (32, 8, 5)
        # pos_values = pos_values.view(batch_size, n_generators, 1)
        # x = torch.cat((x, pos_values), dim=2)
        # print("x:", x)
        # print("x shape:", x.shape)

        
        # output = self.generator_torch_layer(x)
        output = torch.stack([self.generator_torch_layer(x, self.q_params[_]) for _ in range(self.n_generators)])
        # output = JAXQuantumFunction.apply(x, self.q_params[0], self.q_params[1])
        # print("output shape:", output.shape)

        output = output.view(batch_size, n_generators, -1)
        output = output.view(batch_size, -1)
        flattened_order = [j for sub in ordering for j in sub]
        # print("output shape:", output.shape)
        output = output[:, flattened_order]
        # print("output shape:", output.shape)
        # output = output.reshape(batch_size, patch_size)
        # print("patches shape:", output.shape)
        
        return output

# %%
# flattened_order = [j for sub in ordering for j in sub]
# flattened_order

# %%
position_encoding
# Out:
# 0

# %%
lrG = 0.3
lrD = 0.05
num_iter = 500

gen_losses = []
disc_losses = []
discriminator = D_PCNE_QGAN().to(device)

# generator = QuantumGenerator_PCNE_QGAN(n_generators, position_encoding, 0, 6).to(device)
generator = QuantumGenerator_MOSAIQ(n_generators, position_encoding, 0, 6).to(device)

criterion = nn.BCELoss()

# %%
def relu(x):
    return x * (x > 0)
def get_noise_upper_bound(gen_loss, disc_loss, original_ratio):
    R = disc_loss.detach().cpu().numpy()/gen_loss.detach().cpu().numpy()
    return math.pi/8 + (5 *math.pi / 8) * relu(np.tanh((R - (original_ratio))))

# %%
original_ratio = None
upper_bounds = [math.pi/8]
results = []
generated_images = []

# %%
for name, param in generator.named_parameters():
    if param.requires_grad:
        print(f"Layer name: {name} | Trainable: {param.requires_grad} | Size: {param.size()}")
# Out:
# Layer name: q_params.0 | Trainable: True | Size: torch.Size([6, 8])
# Layer name: q_params.1 | Trainable: True | Size: torch.Size([6, 8])
# Layer name: q_params.2 | Trainable: True | Size: torch.Size([6, 8])
# Layer name: q_params.3 | Trainable: True | Size: torch.Size([6, 8])
# Layer name: q_params.4 | Trainable: True | Size: torch.Size([6, 8])

# %%
optD = optim.SGD(discriminator.parameters(), lr=lrD)
optG = optim.SGD(generator.parameters(), lr=lrG)
real_labels = torch.full((batch_size,), 1.0, dtype=torch.float, device=device)
fake_labels = torch.full((batch_size,), 0.0, dtype=torch.float, device=device)
counter = 0

# noise_upper_bound = math.pi/8

# %%
print('Training...')
for e in tqdm(range(num_iter)):
    st = time.time()
    for i, train_pair in enumerate(dataloader):
        pca_data = train_pair
        data = pca_data.reshape(batch_size, pca_dims)
        real_data = data.to(device).to(torch.float32)
        noise = torch.rand(batch_size, n_qubits-position_encoding, device=device)
        
        fake_data = generator(noise)
        
        discriminator.zero_grad()
        outD_real = discriminator(real_data).view(-1)
        outD_fake = discriminator(fake_data.detach()).view(-1)
        errD_real = criterion(outD_real, real_labels)
        errD_fake = criterion(outD_fake, fake_labels)

        # print("shapes:", outD_fake.shape, fake_labels.shape)
        
        errD_real.backward()
        errD_fake.backward()
        errG = criterion(outD_fake, real_labels)
        errD = errD_real + errD_fake
        
        # gen_losses.append(errG.detach().cpu().numpy())
        # disc_losses.append(errD.detach().cpu().numpy())
        
        gen_losses.append(errG.detach().cpu().numpy())
        disc_losses.append(errD.detach().cpu().numpy())

        optD.step()

        # Train the generator
        generator.zero_grad()
        outD_fake = discriminator(fake_data).view(-1)
        errG = criterion(outD_fake, real_labels)
        errG.backward()
        optG.step()
        if original_ratio is None:
            original_ratio = errD.detach().cpu().numpy()/errG.detach().cpu().numpy()
        noise_upper_bound = get_noise_upper_bound(errG, errD, original_ratio)
        upper_bounds.append(noise_upper_bound)
        np.save(f'upper_bounds_{label_to_keep_name}', upper_bounds)
        counter += 1      
        if counter % 20 == 0:  
            test_images = generator(noise).detach().cpu().numpy()
            test_images = pca.inverse_transform(test_images)
            fid = calculate_fid(test_images.reshape([batch_size, 784]), train_data)
            test_images = scale_data(test_images,[0,1])
            real_images = []
            np.save(f'gen_loss_{label_to_keep_name}', gen_losses)
            np.save(f'disc_loss_{label_to_keep_name}', disc_losses)
            from PIL import Image 
            im = np.reshape(test_images[0], [28, 28])
            new_im = np.zeros([28,28])
            for i in range(28):
                for j in range(28):
                    if im[i][j] > .5:
                        new_im[i][j] = 0.0
                    else:
                        new_im[i][j] = 1.0
            im = Image.fromarray(np.uint8(255-(new_im*255)))
            
            print("FID score:", fid)
            
            # im = im.save(os.path.join("../QGAN/gen_images_dist",f"{label_to_keep_name}_{counter}.png"))  # original
            # im = im.save(os.path.join("../QGAN/gen_images_dist simple rot",f"{label_to_keep_name}_{counter}.png"))  # naive rotation
            # im = im.save(os.path.join("../QGAN/gen_images_dist same generator no noise encoder",f"{label_
            im = im.save(os.path.join("../QGAN/gen_images_dist same generator with conditioned noise encoder",f"{label_to_keep_name}_{counter}.png"))  # naive rotationto_keep_name}_{counter}.png"))  # naive rotation
            
            torch.save(generator.state_dict(), f"generator_{label_to_keep_name}")
            torch.save(discriminator.state_dict(), f"disc_{label_to_keep_name}")

    print(i, "time taken:", time.time() - st)
# Out:
# Training...
#   0%|                                                                                     | 0/500 [09:18<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[214], line 10
#       7 real_data = data.to(device).to(torch.float32)
#       8 noise = torch.rand(batch_size, n_qubits-position_encoding, device=device)
# ---> 10 fake_data = generator(noise)
#      12 discriminator.zero_grad()
#      13 outD_real = discriminator(real_data).view(-1)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# Cell In[199], line 57, in QuantumGenerator_MOSAIQ.forward(self, x)
#      42 batch_size, len_data = x.shape
#      44 # x = x.unsqueeze(1)  # (32, 1, 5)
#      45 # x = x.expand(-1, n_generators, -1)  # (32, 8, 5)
#      46 # # print("x:", x)
#    (...)     55
#      56 # output = self.generator_torch_layer(x)
# ---> 57 output = torch.stack([self.generator_torch_layer(x, self.q_params[_]) for _ in range(self.n_generators)])
#      58 # output = JAXQuantumFunction.apply(x, self.q_params[0], self.q_params[1])
#      59 # print("output shape:", output.shape)
#      61 output = output.view(batch_size, n_generators, -1)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# Cell In[197], line 9, in QuantumMLP_MOSAIQ.forward(self, x, weight)
#       6 def forward(self, x, weight):
#       7     # out = JAXQuantumFunction.apply(x, self.q_params[0], self.q_params[1])
#       8     # print("shape of x:", x.shape)
# ----> 9     out = JAXQuantumFunction.apply(x, weight)
#      11     return out
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/torch/autograd/function.py:583, in Function.apply(cls, *args, **kwargs)
#     580 if not torch._C._are_functorch_transforms_active():
#     581     # See NOTE: [functorch vjp and autograd interaction]
#     582     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 583     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     585 if not is_setup_ctx_defined:
#     586     raise RuntimeError(
#     587         "In order to use an autograd.Function with functorch transforms "
#     588         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     589         "staticmethod. For more details, please see "
#     590         "https://pytorch.org/docs/main/notes/extending.func.html"
#     591     )
#
# Cell In[194], line 25, in JAXQuantumFunction.forward(ctx, inputs, weights)
#      22     return out
#      24 # 2. Compute VJP on the consolidated model
# ---> 25 val, jax_vjp_fn = jax.vjp(consolidated_model, jax_in, jax_w)
#      27 ctx.jax_vjp_fn = jax_vjp_fn
#      28 # Return to Torch
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/api.py:2199, in vjp(***failed resolving arguments***)
#    2196 check_callable(fun)
#    2197 wrapped_fun = lu.wrap_init(
#    2198     fun, debug_info=debug_info("vjp", fun, primals, {}))
# -> 2199 return _vjp(wrapped_fun, *primals, has_aux=has_aux)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/api.py:2209, in _vjp(fun, has_aux, *primals)
#    2207 if not has_aux:
#    2208   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2209   out_primals_flat, out_pvals, jaxpr, residuals = ad.linearize(
#    2210       flat_fun, *primals_flat, is_vjp=True)
#    2211   out_tree = out_tree()
#    2212   aux = aux_tree = None
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/ad.py:281, in linearize(traceable, has_aux, is_vjp, *primals)
#     279 def linearize(traceable: lu.WrappedFun, *primals, has_aux=False, is_vjp=False):
#     280   if config.use_direct_linearize.value:
# --> 281     return direct_linearize(traceable, primals, has_aux=has_aux, is_vjp=is_vjp)
#     282   if not has_aux:
#     283     jvpfun = jvp(traceable)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/ad.py:256, in direct_linearize(traceable, primals, has_aux, is_vjp)
#     253   aux = [x.primal if type(x) is LinearizeTracer and x._trace.tag is tag
#     254          else x for x in aux]
#     255 else:
# --> 256   ans = traceable.call_wrapped(*tracers)
#     257   aux = None
#     258 out_primals, out_tangents = unzip2(map(lin_trace.to_primal_tangent_pair, ans))
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# Cell In[194], line 18, in JAXQuantumFunction.forward.<locals>.consolidated_model(i, w)
#      16 def consolidated_model(i, w):
#      17     # print("shape of i, w, w_ne in JAXQuantumFunction:", i.shape, w.shape, w_ne.shape)
# ---> 18     out = vmap_circuit(i, w)
#      19     # print("shape of out in JAXQuantumFunction:", out.shape)
#      20     if isinstance(out, (list, tuple)):
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/api.py:1217, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1214 try:
#    1215   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1216                                 explicit_mesh_axis)
# -> 1217   out_flat, inferred_out_axes = batching.batch(
#    1218       flat_fun, axis_data, in_axes_flat,
#    1219       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1220       sum_match=sum_match
#    1221   ).call_wrapped(*args_flat)
#    1222 except batching.SpecMatchError as e:
#    1223   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/batching.py:371, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     369 tag = TraceTag()
#     370 with source_info_util.transform_name_stack('vmap'):
# --> 371   outs, out_dim_srcs, trace = f(tag, in_dims, *in_vals)
#     372 with core.ensure_no_leaks(trace): del trace
#     373 return outs, out_dim_srcs
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/batching.py:390, in _batch_inner(f, axis_data, out_dim_dests, sum_match, tag, in_dims, *in_vals)
#     384 # TODO(yashkatariya): Instead of `add_explicit_mesh_axis_names`, we should
#     385 # create a new mesh by removing the axis_data.explicit_mesh_axis from it.
#     386 with (core.set_current_trace(trace),
#     387       core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     388       core.add_spmd_axis_names(axis_data.spmd_name),
#     389       core.add_explicit_mesh_axis_names(axis_data.explicit_mesh_axis)):
# --> 390   outs = f(*in_tracers)
#     391   out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     392   out_vals, out_dim_srcs = unzip2(
#     393       map(partial(from_elt, trace, axis_data.size, axis_data.explicit_mesh_axis, sum_match),  # pyrefly: ignore[no-matching-overload]  # pyrefly#2385
#     394           range(len(outs)), outs, out_dim_dests))
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/batching.py:120, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     116 @lu.transformation_with_aux2
#     117 def flatten_fun_for_vmap(f: Callable,
#     118                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     119   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 120   ans = f(*py_args, **py_kwargs)
#     121   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     122   store.store(out_tree)
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/pjit.py:256, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     252   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     253                      "`jit`, but 'no_tracing' is set")
#     254 p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     255 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 256  executable, pgle_profiler, const_args) = _run_python_pjit(
#     257      p, args_flat, fun, args, kwargs)
#     259 maybe_fastpath_data = _get_fastpath_data(
#     260     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     261     pgle_profiler, const_args)
#     263 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/pjit.py:144, in _run_python_pjit(p, args_flat, fun, args, kwargs)
#     141   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     142       *args_flat, **p.params)
#     143 else:
# --> 144   out_flat = jit_p.bind(*args_flat, **p.params)
#     145   compiled = None
#     146   profiler = None
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:636, in Primitive.bind(self, *args, **params)
#     634 def bind(self, *args, **params):
#     635   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 636   return self._true_bind(*args, **params)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:652, in Primitive._true_bind(self, *args, **params)
#     650 trace_ctx.set_trace(eval_trace)
#     651 try:
# --> 652   return self.bind_with_trace(prev_trace, args, params)
#     653 finally:
#     654   trace_ctx.set_trace(prev_trace)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:664, in Primitive.bind_with_trace(self, trace, args, params)
#     662     with set_current_trace(trace):
#     663       return self.to_lojax(*args, **params)  # type: ignore
# --> 664   return trace.process_primitive(self, args, params)
#     665 trace.process_primitive(self, args, params)  # may raise lojax error
#     666 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/batching.py:260, in BatchTrace.process_primitive(self, p, tracers, params)
#     255 if p in fancy_primitive_batchers:
#     256   # TODO(yashkatariya): Remove remove_explicit_mesh_axis_names when vmap
#     257   # mesh ctx is correctly set.
#     258   with (core.set_current_trace(self.parent_trace),
#     259         core.remove_explicit_mesh_axis_names(self.axis_data.explicit_mesh_axis)):
# --> 260     val_out, dim_out = fancy_primitive_batchers[p](
#     261         self.axis_data, vals_in, dims_in, **params)
#     262     src = source_info_util.current()
#     263     if p.multiple_results:
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/pjit.py:1501, in _pjit_batcher(axis_data, vals_in, dims_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs)
#    1496 if not (all(l is None for l in in_layouts) and
#    1497         all(l is None for l in out_layouts)):
#    1498   raise NotImplementedError(
#    1499       'Concrete layouts are not supported for vmap(jit).')
# -> 1501 vals_out = jit_p.bind(
#    1502   *vals_in,
#    1503   jaxpr=new_jaxpr,
#    1504   in_shardings=in_shardings,
#    1505   out_shardings=out_shardings,
#    1506   in_layouts=in_layouts,
#    1507   out_layouts=out_layouts,
#    1508   donated_invars=donated_invars,
#    1509   ctx_mesh=ctx_mesh,
#    1510   name=name,
#    1511   keep_unused=keep_unused,
#    1512   inline=inline,
#    1513   compiler_options_kvs=compiler_options_kvs)
#    1515 return vals_out, axes_out
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:636, in Primitive.bind(self, *args, **params)
#     634 def bind(self, *args, **params):
#     635   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 636   return self._true_bind(*args, **params)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:652, in Primitive._true_bind(self, *args, **params)
#     650 trace_ctx.set_trace(eval_trace)
#     651 try:
# --> 652   return self.bind_with_trace(prev_trace, args, params)
#     653 finally:
#     654   trace_ctx.set_trace(prev_trace)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:664, in Primitive.bind_with_trace(self, trace, args, params)
#     662     with set_current_trace(trace):
#     663       return self.to_lojax(*args, **params)  # type: ignore
# --> 664   return trace.process_primitive(self, args, params)
#     665 trace.process_primitive(self, args, params)  # may raise lojax error
#     666 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/ad.py:790, in LinearizeTrace.process_primitive(self, primitive, args, params)
#     788 lin = primitive_linearizations.get(primitive, fallback)
#     789 with core.set_current_trace(self.parent_trace):
# --> 790   primal_out, tangent_nzs_out, residuals, linearized = lin(
#     791       self.is_vjp, tangent_nzs, *primals_in, **params)
#     792 with (core.set_current_trace(self.tangent_trace),
#     793       source_info_util.set_name_stack(self._name_stack_suffix())):
#     794   tangent_out = linearized(residuals, *tangents_in)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/pjit.py:1664, in _pjit_linearize(is_vjp, nzs, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *primals_in)
#    1661   return tuple(x for nz, x in zip(is_nz_l, l) if nz)
#    1663 assert len(in_shardings) == len(primal_jaxpr.in_avals)
# -> 1664 ans = jit_p.bind(*primals_in, jaxpr=primal_jaxpr,
#    1665                  in_shardings=in_shardings,
#    1666                  out_shardings=primal_out_shardings,
#    1667                  in_layouts=in_layouts,
#    1668                  out_layouts=primal_out_layouts,
#    1669                  donated_invars=donated_invars,
#    1670                  ctx_mesh=ctx_mesh,
#    1671                  name=name,
#    1672                  keep_unused=keep_unused,
#    1673                  inline=inline,
#    1674                  compiler_options_kvs=compiler_options_kvs)
#    1675 ans = subs_list(out_fwd, ans, ans)
#    1676 ans = subs_list(in_fwd, primals_in, ans)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:636, in Primitive.bind(self, *args, **params)
#     634 def bind(self, *args, **params):
#     635   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 636   return self._true_bind(*args, **params)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:652, in Primitive._true_bind(self, *args, **params)
#     650 trace_ctx.set_trace(eval_trace)
#     651 try:
# --> 652   return self.bind_with_trace(prev_trace, args, params)
#     653 finally:
#     654   trace_ctx.set_trace(prev_trace)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:664, in Primitive.bind_with_trace(self, trace, args, params)
#     662     with set_current_trace(trace):
#     663       return self.to_lojax(*args, **params)  # type: ignore
# --> 664   return trace.process_primitive(self, args, params)
#     665 trace.process_primitive(self, args, params)  # may raise lojax error
#     666 raise Exception(f"couldn't apply typeof to args: {args}")
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/core.py:1208, in EvalTrace.process_primitive(self, primitive, args, params)
#    1206 args = map(full_lower, args)
#    1207 check_eval_args(args)
# -> 1208 return primitive.impl(*args, **params)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/pjit.py:1288, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1280 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1281 cache_key = pxla.JitGlobalCppCacheKeys(
#    1282     donate_argnums=donated_argnums, donate_argnames=None,
#    1283     device=None, backend=None,
#    (...)   1286     in_layouts_treedef=None, in_layouts_leaves=in_layouts,
#    1287     out_layouts_treedef=None, out_layouts_leaves=out_layouts)
# -> 1288 return xc._xla.pjit(
#    1289     name, f, call_impl_cache_miss, [], [], cache_key,
#    1290     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1291     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/pjit.py:1264, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1260 def call_impl_cache_miss(*args_, **kwargs_):
#    1261   # args_ do not include the const args
#    1262   # See https://docs.jax.dev/en/latest/internals/constants.html.
#    1263   # TODO(necula): remove num_const_args when fixing the C++ path
# -> 1264   out_flat, compiled, pgle_profiler, const_args = _pjit_call_impl_python(
#    1265       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1266       out_shardings=out_shardings, in_layouts=in_layouts,
#    1267       out_layouts=out_layouts, donated_invars=donated_invars,
#    1268       ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1269       inline=inline, compiler_options_kvs=compiler_options_kvs)
#    1270   fastpath_data = _get_fastpath_data(
#    1271       compiled, tree_structure(out_flat), args, out_flat,
#    1272       jaxpr.effects, jaxpr.consts, pgle_profiler,
#    1273       const_args)
#    1274   return out_flat, fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/pjit.py:1217, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1206 arg_types = map(convert_to_metaty, args)
#    1207 computation = _resolve_and_lower(
#    1208     arg_types, jaxpr=jaxpr, in_shardings=in_shardings,
#    1209     out_shardings=out_shardings, in_layouts=in_layouts,
#    (...)   1215     compiler_options_kvs=compiler_options_kvs,
#    1216 )
# -> 1217 compiled = computation.compile()
#    1219 # This check is expensive so only do it if enable_checks is on.
#    1220 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/pxla.py:2516, in MeshComputation.compile(self, compiler_options, device_assignment)
#    2513 if use_cache and self._executable is not None:
#    2514   return self._executable
# -> 2516 executable = UnloadedMeshExecutable.from_hlo(
#    2517     self._name, self._hlo, **self.compile_args,
#    2518     compiler_options_kvs=compiler_options_kvs,
#    2519     device_list=compilation_device_list)
#    2520 if use_cache:
#    2521   self._executable = executable
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/pxla.py:3063, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    3060       break
#    3062 util.test_event("pxla_cached_compilation")
# -> 3063 xla_executable = _cached_compilation(
#    3064     hlo, name, mesh, spmd_lowering,
#    3065     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    3066     allow_prop_to_outputs, tuple(host_callbacks), backend, device_list,
#    3067     pmap_nreps, compiler_options_kvs, pgle_profiler)
#    3069 if auto_spmd_lowering:
#    3070   assert mesh is not None
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/interpreters/pxla.py:2844, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2836 compile_options = create_compile_options(
#    2837     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2838     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2839     dev, pmap_nreps, compiler_options)
#    2841 with dispatch.log_elapsed_time(
#    2842     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2843     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2844   xla_executable = compiler.compile_or_get_cached(
#    2845       backend, computation, dev, compile_options, host_callbacks,
#    2846       da, pgle_profiler)
#    2847 return xla_executable
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/compiler.py:478, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, executable_devices, pgle_profiler)
#     476 else:
#     477   log_persistent_cache_miss(module_name, cache_key)
# --> 478   return _compile_and_write_cache(
#     479       backend,
#     480       computation,
#     481       executable_devices,
#     482       compile_options,
#     483       host_callbacks,
#     484       module_name,
#     485       cache_key,
#     486   )
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/compiler.py:746, in _compile_and_write_cache(backend, computation, executable_devices, compile_options, host_callbacks, module_name, cache_key)
#     736 def _compile_and_write_cache(
#     737     backend: xc.Client,
#     738     computation: ir.Module,
#    (...)    743     cache_key: str,
#     744 ) -> xc.LoadedExecutable:
#     745   start_time = time.monotonic()
# --> 746   executable = backend_compile_and_load(
#     747       backend, computation, executable_devices, compile_options, host_callbacks
#     748   )
#     749   compile_time = time.monotonic() - start_time
#     750   _cache_write(
#     751       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     752   )
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/profiler.py:384, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     381 @wraps(func)
#     382 def wrapper(*args, **kwargs):
#     383   with TraceAnnotation(name, **decorator_kwargs):
# --> 384     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/posmosaiq/lib/python3.14/site-packages/jax/_src/compiler.py:362, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     353       return backend.compile_and_load(
#     354           module,
#     355           executable_devices=executable_devices,
#     356           compile_options=options,
#     357           host_callbacks=host_callbacks,
#     358       )
#     359     # Some backends don't have `host_callbacks` option yet
#     360     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     361     # to take in `host_callbacks`
# --> 362     return backend.compile_and_load(
#     363         module,
#     364         executable_devices=executable_devices,
#     365         compile_options=options,
#     366     )
#     367 except _jax.JaxRuntimeError as e:
#     368   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %%
n_qubits
position_encoding

# %%
# vars = []
# for label in ["5"]:
#     var = []
#     label_to_keep_name = label
#     generator.load_state_dict(torch.load(f"generator_{label_to_keep_name}"))
#     outputs = np.zeros([25, 5, 784])
#     noise_max = np.load(f'upper_bounds_{label_to_keep_name}.npy')
#     for i in range(25):
#         noise = torch.rand(n_generators, n_qubits-position_encoding, device=device).to(device) * noise_max[i]
#         output = pca.inverse_transform(generator(noise).detach().cpu().numpy())
#         outputs[i] = output
#     outputs = outputs.reshape([125, 784])
#     mean = np.mean(outputs, axis=0)
#     for i in range(outputs.shape[0]):
#         var.append(np.sum(np.square(outputs[i] - mean)))
#     x = np.sort(var)
#     y = np.arange(200) / float(200)
#     vars.append((x,y))
# plt.plot(vars[0][0], vars[0][1], marker='o', label='No ADJ')
# plt.plot(vars[1][0], vars[1][1], marker='o', label='ADJ')
# np.save('vars', vars)
# plt.legend()
# plt.show()

# %%
train_pair = next(iter(dataloader))
pca_data = train_pair

# %%
train_pair.shape
# Out:
# torch.Size([32, 40])

# %%
data = pca_data.reshape(batch_size, pca_dims)

# %%
data.shape
# Out:
# torch.Size([32, 40])

# %%
real_data = data.to(device).to(torch.float32)
noise_upper_bound = 1
noise = torch.rand(batch_size, n_qubits-position_encoding, device=device) * noise_upper_bound

# %%
fake_data = generator(noise)

# %%
noise.shape
# Out:
# torch.Size([32, 8])

# %%
fake_data.shape
# Out:
# torch.Size([32, 40])

# %%
discriminator.zero_grad()

# %%
outD_real = discriminator(real_data).view(-1)

# %%
outD_fake = discriminator(fake_data.detach()).view(-1)

# %%
outD_real
# Out:
# tensor([1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 0.9998,
#         1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 0.9911, 1.0000,
#         1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 0.9982,
#         1.0000, 1.0000, 1.0000, 1.0000, 1.0000], device='cuda:0',
#        grad_fn=<ViewBackward0>)

# %%
outD_fake
# Out:
# tensor([2.1563e-05, 9.9760e-06, 1.0257e-05, 5.7637e-05, 1.5361e-05, 1.7297e-05,
#         1.6050e-05, 1.8990e-05, 2.1471e-05, 2.8160e-05, 1.7141e-05, 1.2582e-05,
#         1.6513e-05, 3.1253e-05, 1.4819e-05, 2.2475e-05, 1.5480e-05, 1.7949e-05,
#         5.9841e-05, 9.9795e-06, 1.5732e-05, 1.8170e-05, 2.7111e-05, 1.1133e-05,
#         2.1891e-05, 1.1448e-05, 3.1547e-05, 2.7171e-05, 1.4811e-05, 7.7592e-06,
#         1.8042e-05, 1.0696e-05], device='cuda:0', grad_fn=<ViewBackward0>)

# %%
fake_data__pca_inv = pca.inverse_transform(fake_data.detach().cpu().numpy())

# %%
fake_data__pca_inv = fake_data__pca_inv.reshape(batch_size, 28, 28)

# %%
fake_data__pca_inv.shape
# Out:
# (32, 28, 28)

# %%
plt.imshow(fake_data__pca_inv[0])

# %%
real_data.shape
# Out:
# torch.Size([32, 40])

# %%
plt.imshow(pca.inverse_transform(real_data.detach().cpu().numpy()).reshape(32, 28, 28)[0])

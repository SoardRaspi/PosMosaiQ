# %%
import torch

if torch.cuda.is_available():
    print("CUDA (GPU access) is available.")
    print("Number of GPUs:", torch.cuda.device_count())
    print("Current GPU Name:", torch.cuda.get_device_name(0))
    # Set the device to GPU
    device = torch.device("cuda")
else:
    print("CUDA (GPU access) is not available. Using CPU.")
    # Set the device to CPU
    device = torch.device("cpu")
# Out:
# CUDA (GPU access) is available.
# Number of GPUs: 1
# Current GPU Name: NVIDIA GeForce RTX 2080 Ti
